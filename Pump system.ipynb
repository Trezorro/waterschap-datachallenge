# %%
import pandas as pd

# %%
df = pd.read_excel(r'./data/sewer_model/20180717_dump riodat rioleringsdeelgebieden_matched_to_rainfall_locations.xlsx')
df = df.drop(df.index[0:8])
df.columns = df.iloc[0]
df = df.drop(df.index[0])
df.reset_index(drop= True)
df1 = df['RWZI']=="R.W.Z.I. Den Bosch"
df2 = df[df1]
df2 = df2.drop(columns=['Eigendom', 'Afv cap',  'Begin', 'ONP', 'Type riol st', 'Afv wijze'])
DenBoschPompen = df2

# %%
DenBoschPompen['Afvoer naar'] = DenBoschPompen['Afvoer naar'].fillna(value= 0)
DenBoschPompen
# Out:
# 8    Volgnr         Code       Kern Naam kern      Naam / lokatie  \
# 431     585  HER-BOK-KER  HER-BOK-1  Bokhoven            Bokhoven
# 432     937  HER-BOK-MAA  HER-BOK-1  Bokhoven            Maasdijk
# 439     577  HER-ENG-HAV  HER-ENG-1   Engelen    Geb. 29 Haverley
# 440     576  HER-ENG-HOO  HER-ENG-1   Engelen    Geb. 30 Hoogveld
# 441     575  HER-ENG-KER  HER-ENG-1   Engelen     Geb. 30 Engelen
# ...     ...          ...        ...       ...                 ...
# 1075    857  VUG-VUG-VLI  VUG-VUG-1     Vught      5. Vlierstraat
# 1076    859  VUG-VUG-VOO  VUG-VUG-1     Vught         6. Voorburg
# 1077    845  VUG-VUG-VOS  VUG-VUG-1     Vught      17. Vossenveld
# 1078   1316  VUG-VUG-VUG  VUG-VUG-1     Vught  66. Vughtse Hoeven
# 1079    854  VUG-VUG-ZEE  VUG-VUG-1     Vught        2. Zeehelden
#
# 8                 Afvoer lok.  Afvoer naar                RWZI Afdrukvolgnr  \
# 431   Baronesse van Egmondweg            0  R.W.Z.I. Den Bosch            1
# 432       Bokhovense Maasdijk  HER-BOK-KER  R.W.Z.I. Den Bosch            2
# 439                       NaN  HER-ENG-KER  R.W.Z.I. Den Bosch            3
# 440           Aalscholverlaan  HER-ENG-KER  R.W.Z.I. Den Bosch            2
# 441              Heuvelschans            0  R.W.Z.I. Den Bosch            1
# ...                       ...          ...                 ...          ...
# 1075            Vd Pollstraat  VUG-VUG-NOO  R.W.Z.I. Den Bosch            5
# 1076           Nachtegaallaan  VUG-VUG-NOO  R.W.Z.I. Den Bosch            6
# 1077             Lunettenlaan  VUG-VUG-IJZ  R.W.Z.I. Den Bosch           13
# 1078                Esscheweg  VUG-VUG-MOL  R.W.Z.I. Den Bosch           15
# 1079       J. van Galenstraat  VUG-VUG-ESS  R.W.Z.I. Den Bosch            2
#
# 8    NaN               NaN
# 431  NaN          Bokhoven
# 432  NaN          Maasdijk
# 439  NaN               NaN
# 440  NaN  Geb. 30 Hoogveld
# 441  NaN   Geb. 30 Engelen
# ...   ..               ...
# 1075 NaN               NaN
# 1076 NaN               NaN
# 1077 NaN               NaN
# 1078 NaN               NaN
# 1079 NaN               NaN
#
# [133 rows x 11 columns]

# %%
Eindpompen = DenBoschPompen[DenBoschPompen['Afvoer naar']==0]
Eindpompen
# Out:
# 8    Volgnr         Code       Kern                          Naam kern  \
# 431     585  HER-BOK-KER  HER-BOK-1                           Bokhoven
# 441     575  HER-ENG-KER  HER-ENG-1                            Engelen
# 448     530  HER-HER-CNR  HER-HER-4  Hertogenbosch (Oude Engelenseweg)
# 455     978  HER-HER-HEI  HER-HER-6               Heineken (Brouwerij)
# 460     562  HER-HER-KRU  HER-HER-2     Hertogenbosch (Helftheuvelweg)
# 461     571  HER-HER-MAA  HER-HER-3          Hertogenbosch (Maaspoort)
# 468     559  HER-HER-NOO  HER-HER-5            Hertogenbosch (Rompert)
# 527     269  HEU-DOE-KER  HEU-DOE-1                           Doeveren
# 528    1428  HEU-DOE-PAR  HEU-DOE-2                   injectiepunt Dkr
# 530     271  HEU-DRU-BEE  HEU-DRU-1                             Drunen
# 543     300  HEU-DRU-STA  HEU-DRU-2            Drunen (Stationsstraat)
# 552     284  HEU-ELS-KER  HEU-ELS-1                            Elshout
# 559     306  HEU-HAA-KER  HEU-HAA-1                          Haarsteeg
# 560    1459  HEU-HAA-VAL  HEU-HAA-2                   injectiepunt Dkr
# 561    1159  HEU-HED-GRO  HEU-HED-3                   injectiepunt Dkr
# 562     282  HEU-HED-KER  HEU-HED-1                        Hedikhuizen
# 563    1156  HEU-HED-LAM  HEU-HED-2                   injectiepunt Dkr
# 564     273  HEU-HEE-IND  HEU-HEE-1                           Heesbeen
# 565    1163  HEU-HEE-WES  HEU-HEE-2                   injectiepunt Dkr
# 566    1164  HEU-HEE-WSA  HEU-HEE-2                   injectiepunt Dkr
# 574     589  HEU-OUD-TSR  HEU-OUD-1                         Oudheusden
# 575     315  HEU-VLI-GLA  HEU-VLI-2                 Vlijmen (Het Hoog)
# 576     313  HEU-VLI-HOA  HEU-VLI-2                 Vlijmen (Het Hoog)
# 577     314  HEU-VLI-HOB  HEU-VLI-2                 Vlijmen (Het Hoog)
# 579     308  HEU-VLI-KER  HEU-VLI-1                            Vlijmen
# 1070    842  VUG-VUG-NOO  VUG-VUG-1                              Vught
#
# 8                 Naam / lokatie               Afvoer lok. Afvoer naar  \
# 431                     Bokhoven   Baronesse van Egmondweg           0
# 441              Geb. 30 Engelen              Heuvelschans           0
# 448               Centraal riool           Oude Engelseweg           0
# 455                     Heineken                       NaN           0
# 460            Geb. 21 Kruiskamp            Helftheuvelweg           0
# 461            Geb. 26 Maaspoort  Maaspoortweg / Kobaltweg           0
# 468       Geb. 25 Noord(Rompert)            Tweede Rompert           0
# 527                     Doeveren                       NaN           0
# 528                  Parallelweg                       NaN           0
# 530     Beethovenlaan/Venne West                       NaN           0
# 543         Stationsstraat-noord            Stationsstraat           0
# 552                      Elshout                       NaN           0
# 559                    Haarsteeg                       NaN           0
# 560                       Val bv                       NaN           0
# 561                  Grotestraat                       NaN           0
# 562                  Hedikhuizen                       NaN           0
# 563              Lambertusstraat                       NaN           0
# 564                     Heesbeen               Grotestraat           0
# 565                    Westakker                       NaN           0
# 566                    Westakker                       NaN           0
# 574    Transportriool Oudheusden                       NaN           0
# 575        Glastuinbouw Het Hoog                       NaN           0
# 576                   Het Hoog 1                       NaN           0
# 577                   Het Hoog 2                       NaN           0
# 579                 Vlijmen kern                       NaN           0
# 1070  14. Vught Noord en Centrum            Kamperdijklaan           0
#
# 8                   RWZI Afdrukvolgnr NaN                       NaN
# 431   R.W.Z.I. Den Bosch            1 NaN                  Bokhoven
# 441   R.W.Z.I. Den Bosch            1 NaN           Geb. 30 Engelen
# 448   R.W.Z.I. Den Bosch            1 NaN            Centraal riool
# 455   R.W.Z.I. Den Bosch            0 NaN                       NaN
# 460   R.W.Z.I. Den Bosch            3 NaN         Geb. 21 Kruiskamp
# 461   R.W.Z.I. Den Bosch            1 NaN         Geb. 26 Maaspoort
# 468   R.W.Z.I. Den Bosch            1 NaN    Geb. 25 Noord(Rompert)
# 527   R.W.Z.I. Den Bosch            1 NaN                       NaN
# 528   R.W.Z.I. Den Bosch            1 NaN                       NaN
# 530   R.W.Z.I. Den Bosch            1 NaN  Beethovenlaan/Venne West
# 543   R.W.Z.I. Den Bosch            1 NaN      Stationsstraat-noord
# 552   R.W.Z.I. Den Bosch            1 NaN                   Elshout
# 559   R.W.Z.I. Den Bosch            1 NaN                 Haarsteeg
# 560   R.W.Z.I. Den Bosch            1 NaN                       NaN
# 561   R.W.Z.I. Den Bosch            1 NaN                       NaN
# 562   R.W.Z.I. Den Bosch            1 NaN               Hedikhuizen
# 563   R.W.Z.I. Den Bosch            1 NaN                       NaN
# 564   R.W.Z.I. Den Bosch            1 NaN                  Heesbeen
# 565   R.W.Z.I. Den Bosch            1 NaN                       NaN
# 566   R.W.Z.I. Den Bosch            2 NaN                       NaN
# 574   R.W.Z.I. Den Bosch            1 NaN                       NaN
# 575   R.W.Z.I. Den Bosch            3 NaN                       NaN
# 576   R.W.Z.I. Den Bosch            1 NaN                Het Hoog 1
# 577   R.W.Z.I. Den Bosch            2 NaN                Het Hoog 2
# 579   R.W.Z.I. Den Bosch            1 NaN              Vlijmen kern
# 1070  R.W.Z.I. Den Bosch           14 NaN                       NaN

# %%
#for i in DenBoschPompen.iterrows():
#    for j in Bokhoven:
#        if DenBoschPompen['Afvoer naar'] == j:
#            Bokhoven.append(j)

# %%
# gebruik codes voor locaties want die zijn unique, sommige 'naam / lokatie' komen dubbel voor.
#lange methode
Bokhoven = ['HER-BOK-KER']
Haarsteeg = ['HEU-HAA-KER']
Helftheuvelweg = ['HER-HER-KRU']
Maaspoort = ['HER-HER-MAA']
OudenEngelseweg = ['HER-HER-CNR']
Rompert = ['HER-HER-NOO']


for i in DenBoschPompen.index:
    if DenBoschPompen['Afvoer naar'][i] in Bokhoven:
         Bokhoven.append(DenBoschPompen['Code'][i])

for i in DenBoschPompen.index:
    if DenBoschPompen['Afvoer naar'][i] in Haarsteeg:
         Haarsteeg.append(DenBoschPompen['Code'][i])

for i in DenBoschPompen.index:
    if DenBoschPompen['Afvoer naar'][i] in Helftheuvelweg:
         Helftheuvelweg.append(DenBoschPompen['Code'][i])
         #DenBoschPompen.drop(DenBoschPompen[i], inplace = True)

for i in DenBoschPompen.index:
    if DenBoschPompen['Afvoer naar'][i] in Maaspoort:
         Maaspoort.append(DenBoschPompen['Code'][i])
         #DenBoschPompen.drop(DenBoschPompen[i], inplace = True)

for i in DenBoschPompen.index:
    if DenBoschPompen['Afvoer naar'][i] in OudenEngelseweg:
         OudenEngelseweg.append(DenBoschPompen['Code'][i])
         #DenBoschPompen.drop(DenBoschPompen[i], inplace = True)

for i in DenBoschPompen.index:
    if DenBoschPompen['Afvoer naar'][i] in Rompert:
         Rompert.append(DenBoschPompen['Code'][i])
         #DenBoschPompen.drop(DenBoschPompen[i], inplace = True)

# %%
#kortere methode
Bokhoven = ['HER-BOK-KER']
Haarsteeg = ['HEU-HAA-KER']
Helftheuvelweg = ['HER-HER-KRU']
Maaspoort = ['HER-HER-MAA']
OudenEngelseweg = ['HER-HER-CNR']
Rompert = ['HER-HER-NOO']

pompen = [Bokhoven, Haarsteeg, Helftheuvelweg, Maaspoort, OudenEngelseweg, Rompert]

for y in pompen:
    for i in DenBoschPompen.index:
        if DenBoschPompen['Afvoer naar'][i] in y:
             y.append(DenBoschPompen['Code'][i])
# Out:
# ['HER-HER-NOO', 'HER-HER-HER', 'HER-HER-STO']
